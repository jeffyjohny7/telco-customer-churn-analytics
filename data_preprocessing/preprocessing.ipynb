# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
# 1. Load Data
df = pd.read_csv("C:/Users/jeffy/LLMOPs projects/Customer Churn Analytics/data/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
# 2. Clean 'TotalCharges' (Convert blanks to NaN, then to float)
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'].replace(' ', pd.NA))

# %%
# 4. Feature Engineering for ML (Encoding Categoricals)
le = LabelEncoder()
df['Churn_Binary'] = le.fit_transform(df['Churn']) # Yes=1, No=0

# %%
df['TotalCharges'] = df['TotalCharges'].fillna(df['TotalCharges'].median())

# %%
# 3. Create a clean CSV for SQL/Looker Studio
df.to_csv('cleaned_telco_churn.csv', index=False)

# %%
# 1. Drop useless ID
df = df.drop('customerID', axis=1)

# %%
# 2. Fix TotalCharges (Convert to numeric, fill blanks with median)
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'].replace(' ', pd.NA))
df['TotalCharges'] = df['TotalCharges'].fillna(df['TotalCharges'].median())

# %%
# 3. Split into X (features) and y (target)
X = df.drop('Churn', axis=1)
y = df['Churn'].map({'Yes': 1, 'No': 0}) # Convert Yes/No to 1/0

# %%
# 4. One-Hot Encode all those string categories!
X = pd.get_dummies(X, drop_first=True)

# %%
X.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 31 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   SeniorCitizen                          7043 non-null   int64
#  1   tenure                                 7043 non-null   int64
#  2   MonthlyCharges                         7043 non-null   float64
#  3   TotalCharges                           7043 non-null   float64
#  4   Churn_Binary                           7043 non-null   int64
#  5   gender_Male                            7043 non-null   bool
#  6   Partner_Yes                            7043 non-null   bool
#  7   Dependents_Yes                         7043 non-null   bool
#  8   PhoneService_Yes                       7043 non-null   bool
#  9   MultipleLines_No phone service         7043 non-null   bool
#  10  MultipleLines_Yes                      7043 non-null   bool
# ...

# %%
X = X.drop('Churn_Binary', axis=1)
